# %%
import spacy

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# %%
# Example text
text = """Ram visited a shop. He purchased milk, and later he returned to his home."""

# %%
# Process the text with spaCy
doc = nlp(text)

# %%
# Function to resolve pronouns to their antecedents
def resolve_pronouns(doc):
    resolved_text = []
    last_subject = None

    for sent in doc.sents:
        sent_resolved = []
        for token in sent:
            if token.pos_ == 'PRON' and last_subject:
                sent_resolved.append(last_subject.text)
            else:
                if token.dep_ == 'nsubj':
                    last_subject = token
                sent_resolved.append(token.text)
        resolved_text.append(' '.join(sent_resolved))

    return ' '.join(resolved_text)

# %%
# Get the resolved text
resolved_text = resolve_pronouns(doc)

print("Original text:")
print(text)
print("\nResolved text:")
print(resolved_text)
# Out:
# Original text:
# Ram visited a shop. He purchased milk, and later he returned to his home.
#
# Resolved text:
# Ram visited a shop . Ram purchased milk , and later Ram returned to Ram home .

# %% [markdown]
# **Abishek** **Acharya** **BoCE**/**06**
